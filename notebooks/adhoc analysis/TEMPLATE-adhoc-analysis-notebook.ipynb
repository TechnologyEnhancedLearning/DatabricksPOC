# %% [markdown]
# # Contribution Required JJJJ
# - ⚠️This is purely an example template to provoke discussion it should be replaced with a document authored by the team
# - Recommendations
#   - what is the shortest, simplest, least onerous version of this we come up with?
#   - what would you find most useful from this document, what is most useful to remind you at a glance about the work
#   - some thought is required to ensure it is useful for AI too, as being able to ask AI to find out if there is similar work already in the repo would be useful

# %% [markdown]
# # Follow instructions and delete this top cell
# This template should be copied into your jira ticket's adhoc-analysis folder. Then renamed
#
# TD-<ticket number>-MMyy-<description>
#
# Then complete the template.
#
# The purpose is standardisation and discovery to create opportunities to reuse code, and reduce duplicated requests resulting in duplicate work.

# %% [markdown]
# # Analysis Title
# Plain text ticket number
# [ticket number or name](ticket hyperlink)
#
# ## Date
# - requested, for?
#
# ## Analysis Request
# - Put here the request
#
# ## Request Context
# - put here the context
#
# ## Intended use
#
# ## Who for
# - who commissioned it
#
# ## What about
# - just for context
#
# ## Teams the data may be relevant to
# - to aid discovery if future work from someoneelse relating to same domain occurs in future
#
# ## Domain of the data used to answer request
# - high level

# %%
# %SQL
-- queries
-- extract anything useful to utils or gold

# %% [markdown]
# # Analyst Report
#
# ## Methodology
#
# ## Recommendations
# - put here outwards facing comments, comments to inform future tickets should go in readme in the same folder
#
# ## Limitation
# - put here outwards facing comments, comments to inform future tickets should go in readme in the same folder
#
# ## Comments
# - put here outwards facing comments, comments to inform future tickets should go in readme in the same folder
