# %%
# %fs ls

# %% [markdown]
# remember right of cell you can tell it to format python

# %%
# %skip #skips this cell
err

# %%
dbutils.fs.ls("/")

# %%
# %run /Users/philip.tate@nhs.net/PT Separate Feature Branch/scratch-gitincludeforpoc/utils/.
