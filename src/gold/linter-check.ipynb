# %% [markdown]
# # bad code to lint

# %%
def foo  ( x ,y= 5  ) : return x+y
a=[1,2,3,4]
b=[x for x in a if x>2 if x<4 ]
c=foo( 10 )
print(  "Result is:",c)
exec("d=42")
eval("print('d is',d)")
lambda_fun = lambda x:x*2; print(lambda_fun(7))
class BAD_class:pass
