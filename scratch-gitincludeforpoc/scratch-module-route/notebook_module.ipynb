# %% [markdown]
# # Notebook modules
#
# ## Conclusions
# - dont import notebooks turn it into py files otherwise need to use run and thats global, you cant modulize the notebooks well
# - if you want to run them a seperate cell and %run will give run the file and give you all the functions as global functions, it prints the md files too which is nice so you can write "You have made x y z available ..."
#
# ## Table
#
# | Type         | Found ✓ ✗| Notes |
# |--------------|-------|---|
# | py local     |       |    |
# | py dab       |       |  |
# | py staging   |       |  |
# | nb local     |       |  |
# | nb dab       |       |  |
# | nb staging   |       |  |
# | py pipeline  |       |  |
# | nb pipeline  |       |  |
# | py github    |       |  |
# | nb github    |       |  |

# %%
def notebook_module_function_one():
  return "notebook_module_function_one output"

# %%
def notebook_module_function_two():
  return "notebook_module_function_two output"
