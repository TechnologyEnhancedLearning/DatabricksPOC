# %% [markdown]
# # What it is (we share this unlike readme)
# - we take this notebook and drop it in excel to give to the requester
# - we include initial request, however we are not source controlling conversation notes on that live in the linked ticket
#
#
# # Jira tickets number
# [carer ticket](http-ticket123)
#
# # Initial ask
#
# - verbatum

# %% [markdown]
# # Evidence for requester
# Akira team
# # Methodology
#
# # Limitations

# %%
# %SQL

-- what we ran
-- ran against gold layer
-- if what we produce is generally useful we update gold
-- if it isnt it lives in here still

# %%
# %py
import pandas as pd

# Create a simple DataFrame
df = pd.DataFrame({
    "x": [1, 2, 3, 4],
    "y": [10, 20, 15, 25]
})

display(df)
# Out:
# Databricks visualization. Run in Databricks to view.
